# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('../data/df_clean.csv')

# %%
df.columns
# Out:
# Index(['Date', 'Store', 'DayOfWeek', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
#        'CompetitionDistance', 'CompetitionOpenSinceMonth',
#        'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
#        'Promo2SinceYear', 'PromoInterval'],
#       dtype='object')

# %%
# Holidays = zero Customers -> zero Sales: we keep the zeros
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2, figsize=(14, 4))

ax[0].hist(train2.Sales, bins=50);
ax[0].set_title("Sales")

ax[1].hist(train2.Customers, bins=50);
ax[1].set_title("Customers")
# Out:
# Text(0.5, 1.0, 'Customers')

# %%
import seaborn as sns

sns.relplot(
        data=df,
        kind='scatter',
        x="CompetitionDistance",
        y="Sales",
        palette='crest',
        alpha=0.7,
        col='StoreType',
        col_order=['a', 'b', 'c'],
        col_wrap=3)

plt.show()
# Out:
# /tmp/ipykernel_301604/3705643478.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.relplot(

# %%
df.StateHoliday
# Out:
# 0         a
# 1         d
# 2         d
# 3         d
# 4         d
#          ..
# 499414    d
# 499415    d
# 499416    d
# 499417    d
# 499418    d
# Name: StateHoliday, Length: 499419, dtype: object

# %%
grouped_df = df.groupby(['Promo']).agg({'Sales': [np.mean, np.max, np.std]}).reset_index()
categories = grouped_df['Promo'].astype('int')
means = grouped_df['Sales']['mean']
plt.bar(categories, means);

# %%
df.columns
# Out:
# Index(['Date', 'Store', 'DayOfWeek', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
#        'CompetitionDistance', 'CompetitionOpenSinceMonth',
#        'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
#        'Promo2SinceYear', 'PromoInterval'],
#       dtype='object')

# %%
grouped_df = df.groupby(['StoreType']).agg({'Sales': [np.mean, np.max, np.std]}).reset_index()
categories = grouped_df['StoreType']
means = grouped_df['Sales']['mean']
plt.bar(categories, means);

# %%
grouped_df = df.groupby(['StateHoliday']).agg({'Sales': [np.mean, np.max, np.std]}).reset_index()
categories = grouped_df['StateHoliday']
means = grouped_df['Sales']['mean']
plt.bar(categories, means);

# %%
x_vars = ['DayOfWeek', 'CompetitionDistance', 'CompetitionOpenSinceMonth',
       'CompetitionOpenSinceYear', 'Promo2SinceWeek',
       'Promo2SinceYear', 'PromoInterval']

sns.pairplot(df_merge, x_vars=x_vars, y_vars='Sales', hue='StoreType', height=10)
plt.show()

# %%
df.columns
# Out:
# Index(['Date', 'DayOfWeek', 'Sales', 'Customers', 'Promo', 'StoreType',
#        'Assortment', 'CompetitionDistance', 'Promo2', 'PromoInterval',
#        'Competition_Since_X_months', 'weeks_since_promo2'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

x_vars = ['DayOfWeek', 'Customers', 'Promo', 'StoreType',
       'Assortment', 'CompetitionDistance', 'Promo2', 'PromoInterval',
       'Competition_Since_X_months', 'weeks_since_promo2']

sns.pairplot(df, x_vars=x_vars, y_vars='Sales', hue='StoreType')

plt.tight_layout()
plt.show()
